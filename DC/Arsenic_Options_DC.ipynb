# %% [markdown]
# # Arsenic Options
#
# Arsenic is a widely distributed contaminant of groundwater and surface waters that are under the influence of a contaminated groundwater.
#
# 1) What are the best available technologies for removal of arsenic according to the [USEPA contaminant database](https://iaspub.epa.gov/tdb/pages/general/home.do)

# %%
#imports
# !pip install aguaclara
from aguaclara.core.units import unit_registry as u
import aguaclara as ac
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
